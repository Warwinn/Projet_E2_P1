# %%
import pandas as pd
import pickle
data = pd.read_csv("clean_X.csv")

# %%
model = pickle.load(open('finalized_model.sav', 'rb'))
data ['Price'] = model.predict(data)
data
# Out:
#        Age  GrLivArea  LotFrontage  LotArea  GarageArea  Fence   Pool  \
# 0      5.0     1710.0         65.0   8450.0       548.0  False  False
# 1     31.0     1262.0         80.0   9600.0       460.0  False  False
# 2      7.0     1786.0         68.0  11250.0       608.0  False  False
# 3      8.0     2198.0         84.0  14260.0       836.0  False  False
# 4     16.0     1362.0         85.0  14115.0       480.0   True  False
# ...    ...        ...          ...      ...         ...    ...    ...
# 1329   8.0     1647.0         62.0   7917.0       460.0  False  False
# 1330  32.0     2073.0         85.0  13175.0       500.0   True  False
# 1331  69.0     2340.0         66.0   9042.0       252.0   True  False
# 1332  60.0     1078.0         68.0   9717.0       240.0  False  False
# 1333  43.0     1256.0         75.0   9937.0       276.0  False  False
#
#           Price
# 0     189345.40
# 1     171354.63
# 2     200721.00
# 3     232117.00
# 4     267579.50
# ...         ...
# ...

# %%
def predict():
    X = data[['Age','GrLivArea', 'LotFrontage', 'LotArea', 'GarageArea', 'Fence', 'Pool']]
    data['Price'] = model.predict(X)


data = data.apply(predict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_120299/1829498082.py in <module>
#       4
#       5
# ----> 6 data = data.apply(predict)
#
# ~/vscode/Projet_E2_P1/P1_env/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/vscode/Projet_E2_P1/P1_env/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/vscode/Projet_E2_P1/P1_env/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# ...

# %%
data.head()
